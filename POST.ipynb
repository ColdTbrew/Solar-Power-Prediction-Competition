# %% [markdown]
# # Get Weather data by using API

# %%
import requests
import pandas as pd
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
API_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJjUU1wdmZWbkI0NEJpajh5Z3hlaXJxIiwiaWF0IjoxNjk4Mjg3NDkyLCJleHAiOjE3MDAyMzMyMDAsInR5cGUiOiJhcGlfa2V5In0.IjDwGXiZjS10Xq3_X3L5k2-fZ9-wal55j9-hW9166EM"

date = '2023-11-08'
bid_round = 1
weather_fcst = requests.get(f'https://research-api.solarkim.com/cmpt-2023/weathers-forecasts/{date}/{bid_round}', headers={
                            'Authorization': f'Bearer {API_KEY}'
                        }).json()

# %%
weather_test = pd.DataFrame(weather_fcst)
weather_test.head(20)
# Out:
#                          time  cloud   temp  humidity  ground_press  \
# 0   2023-11-07T16:00:00+00:00    0.0  10.18      66.0        1022.0
# 1   2023-11-07T17:00:00+00:00    0.0   9.90      66.0        1023.0
# 2   2023-11-07T18:00:00+00:00    0.0   9.55      65.0        1023.0
# 3   2023-11-07T19:00:00+00:00    0.0   9.40      64.0        1022.0
# 4   2023-11-07T20:00:00+00:00    0.0   9.27      62.0        1022.0
# 5   2023-11-07T21:00:00+00:00    0.0   9.15      61.0        1022.0
# 6   2023-11-07T22:00:00+00:00    0.0   8.94      60.0        1023.0
# 7   2023-11-07T23:00:00+00:00    0.0   9.14      57.0        1023.0
# 8   2023-11-08T00:00:00+00:00    1.0   9.82      53.0        1024.0
# 9   2023-11-08T01:00:00+00:00   27.0  10.83      50.0        1023.0
# 10  2023-11-08T02:00:00+00:00   31.0  12.51      46.0        1023.0
# 11  2023-11-08T03:00:00+00:00   22.0  14.36      41.0        1022.0
# 12  2023-11-08T04:00:00+00:00   19.0  15.57      37.0        1022.0
# ...

# %%
predictor = TabularPredictor.load("../laz2berry/POSTECH/AutogluonModels/cloud")
cloud_err_pred = predictor.predict(weather_test)
cloud_err_pred.head(10)
# Out:
# TBB Warning: The number of workers is currently limited to 19. The request for 95 workers is ignored. Further requests for more workers will be silently ignored until the limit changes.
# 0    21.851181
# 1    21.140085
# 2    24.394253
# 3    24.027067
# 4    23.285515
# 5    23.105316
# 6    22.183868
# 7    21.450193
# 8    23.875624
# 9    21.279099
# Name: cloud_err, dtype: float32

# %%
predictor = TabularPredictor.load("../laz2berry/POSTECH/AutogluonModels/uv")
uv_err_pred = predictor.predict(weather_test)
uv_err_pred.head(10)
# Out:
# 0    0.636950
# 1    0.615635
# 2    0.748892
# 3    0.931760
# 4    1.114152
# 5    1.021897
# 6    0.835705
# 7   -0.498732
# 8   -1.510620
# 9   -2.230559
# Name: uv_err, dtype: float32

# %%
weather_test['cloud'] = weather_test['cloud'] + cloud_err_pred
weather_test.loc[weather_test['uv_idx'] != 0, 'uv_idx'] += uv_err_pred

# %%
weather_test.head(20)
# Out:
#                          time      cloud   temp  humidity  ground_press  \
# 0   2023-11-07T16:00:00+00:00  21.851181  10.18      66.0        1022.0
# 1   2023-11-07T17:00:00+00:00  21.140085   9.90      66.0        1023.0
# 2   2023-11-07T18:00:00+00:00  24.394253   9.55      65.0        1023.0
# 3   2023-11-07T19:00:00+00:00  24.027067   9.40      64.0        1022.0
# 4   2023-11-07T20:00:00+00:00  23.285515   9.27      62.0        1022.0
# 5   2023-11-07T21:00:00+00:00  23.105316   9.15      61.0        1022.0
# 6   2023-11-07T22:00:00+00:00  22.183868   8.94      60.0        1023.0
# 7   2023-11-07T23:00:00+00:00  21.450193   9.14      57.0        1023.0
# 8   2023-11-08T00:00:00+00:00  24.875624   9.82      53.0        1024.0
# 9   2023-11-08T01:00:00+00:00  48.279099  10.83      50.0        1023.0
# 10  2023-11-08T02:00:00+00:00  58.086840  12.51      46.0        1023.0
# 11  2023-11-08T03:00:00+00:00  48.912146  14.36      41.0        1022.0
# ...
